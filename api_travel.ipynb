# %% [markdown]
# # API travel recommandation

# %% [markdown]
# Cette API recommande des destinations de voyage avec comme pays de départ: la France,  l'Allemagne, l'Italie, l'Espagne, les Pays-bas, l'USA, l'Argentine et  l'Arabie saoudite.

# %%
api_keys = "JwBcoLzEegwwTjRDAypurrSvQYQBtEhk"
api_secret="GWuM8LybWntkcEnu"

# %% [markdown]
# # QUELQUES REQUETES POUR COMPRENDRE L'API

# %%
try:
    response = amadeus.shopping.flight_offers_search.get(
        originLocationCode='MAD',
        destinationLocationCode='ATH',
        departureDate='2022-11-01',
        adults=1)
    #print(response.data)
except ResponseError as error:
    print(error)

# %%
from amadeus import Client, ResponseError

amadeus = Client(
    client_id=api_keys,
    client_secret=api_secret
)

# %%
#che=amadeus.reference_data.urls.checkin_links.get(airlineCode='BA')
#che.data

# %%
#exemple1 = amadeus.travel.predictions.trip_purpose.get(originLocationCode='ATH', destinationLocationCode='MAD', departureDate='2022-11-01', returnDate='2022-11-08')
#exemple1.result

# %%
#amadeus.get('/v2/reference-data/urls/checkin-links', airlineCode='BA')

# %%
from amadeus import Location

response = amadeus.reference_data.locations.get(
    keyword='LON',
    subType=Location.ANY
)

# %%
#exemple2 = amadeus.reference_data.recommended_locations.get(cityCodes='MAD', travelerCountryCode='FR')
#exemple2.data

# %%
exemple2 = amadeus.reference_data.recommended_locations.get(cityCodes='LYS,PAR,MAD,LIS,ALG', travelerCountryCode='FR')
exemple2.body
# Out:
# '{"data": [{"subtype": "CITY", "name": "Barcelona", "iataCode": "BCN", "geoCode": {"latitude": 41.297078000000006, "longitude": 2.078464}, "type": "recommended-location", "relevance": 0.86250315}, {"subtype": "CITY", "name": "Porto", "iataCode": "OPO", "geoCode": {"latitude": 41.248055, "longitude": -8.681389}, "type": "recommended-location", "relevance": 0.84573253}, {"subtype": "CITY", "name": "Rome", "iataCode": "ROM", "geoCode": {"latitude": 41.89193, "longitude": 12.511330000000001}, "type": "recommended-location", "relevance": 0.81866579}, {"subtype": "CITY", "name": "Marrakesh", "iataCode": "RAK", "geoCode": {"latitude": 31.606890000000003, "longitude": -8.0363}, "type": "recommended-location", "relevance": 0.79843626}, {"subtype": "CITY", "name": "Tunis", "iataCode": "TUN", "geoCode": {"latitude": 36.85103, "longitude": 10.227219999999999}, "type": "recommended-location", "relevance": 0.79004638}], "meta": {"count": 5, "links": {"self": "https://test.api.amadeus.com/v1/reference-data/recommended-locations?cityCodes=LYS,PAR,MAD,LIS,ALG&travelerCountryCode=FR"}}}'

# %%
#exemple2 = amadeus.reference_data.recommended_locations.get(cityCodes='LYS', travelerCountryCode='FR')
#exemple2.result

# %% [markdown]
# # FACTORISER NOTRE REQUETE

# %%
client_un = { "ville" : {"MAD","PAR"}, "pays" : "FR"}

# %% [markdown]
# Après avoir testé, mon api : j'ai décidé de l'utiliser en demandant à mon client, plusieurs noms de ville qu'il aime bien (jusqu'à 5 villes), le pays de départ et ses dates de voyage. A la suite de cela mon code va transformer les noms en IATA code. Puis va sortir 3 destinations qui pourrait l'interresser. A la suite de cela on va lui proposer pour chaque destination et en fonction de ses dates, 2 billets d'avion.

# %%
from amadeus import Client, ResponseError
def preference_voyage(information_client):
    amadeus = Client(client_id=api_keys,
    client_secret = api_secret)

    from amadeus import Location
    param_client = {}
    for key,value in information_client.items():
        param_client.update({"cityCodes":key, "travelerCountrycode":value})
    
    #preference = amadeus.reference_data.recommended_locations.get(cityCodes = client_un["ville"], travelerCountryCode = client_un["pays"])
    preference = amadeus.reference_data.recommended_locations.get(params = param_client)
    preference=preference.body

    ville_destination={}
    for i in range(3):
        villes_destination=list(preference["data"][i].items())
    return villes_destination

preference_voyage(client_un)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In [173], line 20
#      17         villes_destination=list(preference["data"][i].items())
#      18     return villes_destination
# ---> 20 preference_voyage(client_un)
#
# Cell In [173], line 12, in preference_voyage(information_client)
#       9     param_client.update({"cityCodes":key, "travelerCountrycode":value})
#      11 #preference = amadeus.reference_data.recommended_locations.get(cityCodes = client_un["ville"], travelerCountryCode = client_un["pays"])
# ---> 12 preference = amadeus.reference_data.recommended_locations.get(params = param_client)
#      13 preference=preference.body
#      15 ville_destination={}
#
# File ~/.local/lib/python3.9/site-packages/amadeus/reference_data/_recommended_locations.py:28, in RecommendedLocations.get(self, **params)
#       8 def get(self, **params):
#       9     '''
#      10     Returns a list of destination recommendations
#      11
#    (...)
#      26     :raises amadeus.ResponseError: if the request could not be completed
#      27     '''
# ---> 28     return self.client.get(
#      29         '/v1/reference-data/recommended-locations', **params)
#
# File ~/.local/lib/python3.9/site-packages/amadeus/mixins/http.py:40, in HTTP.get(self, path, **params)
#      19 def get(self, path, **params):
#      20     '''
#      21     A helper function for making generic GET requests calls. It is used by
#      22     every namespaced API GET method.
#    (...)
#      38     :raises amadeus.ResponseError: when the request fails
#      39     '''
# ---> 40     return self.request('GET', path, params)
#
# File ~/.local/lib/python3.9/site-packages/amadeus/mixins/http.py:110, in HTTP.request(self, verb, path, params)
#      88 def request(self, verb, path, params):
#      89     '''
#      90     A helper function for making generic POST requests calls. It is used by
#      91     every namespaced API method. It can be used to make any generic API
#    (...)
#     108     :raises amadeus.ResponseError: when the request fails
#     109     '''
# --> 110     return self._unauthenticated_request(
#     111         verb, path, params,
#     112         self.__access_token()._bearer_token()
#     113     )
#
# File ~/.local/lib/python3.9/site-packages/amadeus/mixins/http.py:126, in HTTP._unauthenticated_request(self, verb, path, params, bearer_token)
#     124 request = self.__build_request(verb, path, params, bearer_token)
#     125 self.__log(request)
# --> 126 return self.__execute(request)
#
# File ~/.local/lib/python3.9/site-packages/amadeus/mixins/http.py:152, in HTTP.__execute(self, request)
#     150 response = Response(http_response, request)._parse(self)
#     151 self.__log(response)
# --> 152 response._detect_error(self)
#     153 return response
#
# File ~/.local/lib/python3.9/site-packages/amadeus/mixins/parser.py:16, in Parser._detect_error(self, client)
#      14 error = self.error_for(self.status_code, self.parsed)
#      15 if error is not None:
# ---> 16     self.__raise_error(error, client)
#
# File ~/.local/lib/python3.9/site-packages/amadeus/mixins/parser.py:67, in Parser.__raise_error(self, error_class, client)
#      65 error = error_class(self)
#      66 error._log(client)
# ---> 67 raise error
#
# ClientError: [400]
# [params[cityCodes]] Invalid parameter in query
# [params[travelerCountrycode]] Invalid parameter in query
# [cityCodes] Missing cityCodes parameter
